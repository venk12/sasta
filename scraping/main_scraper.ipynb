# %%
import os
import subprocess
import pandas as pd
from dotenv import load_dotenv

import albert_heijn.ah_scraper as ah_scraper
import aldi.aldi_scraper as aldi_scraper
import jumbo.jumbo_scraper as jumbo_scraper

load_dotenv()
# Out:
# True

# %%
# Function to create directory if it doesn't exist
def create_directory(path):
    if not os.path.exists(path):
        os.makedirs(path)
        print(f"Created directory: {path}")

# %%
path_ah = 'albert_heijn/'
path_products_ah = 'albert_heijn/ah_products.csv'
create_directory(path_ah)

path_aldi = 'aldi/'
path_products_aldi = 'aldi/aldi_products.csv'
create_directory(path_aldi)

path_jumbo = 'jumbo/'
path_products_jumbo = 'jumbo/jumbo_products.csv'
create_directory(path_jumbo)

path_dirk = 'dirk/'
path_products_dirk = 'dirk/dirk_products.csv'
create_directory(path_dirk)

path_lidl = 'lidl/'
path_products_lidl = 'lidl/lidl_products.csv'
create_directory(path_lidl)

# %%
def fetch_products(name, product_path, scraper_module):
    print(f"Fetching {name} Products...")
    if os.path.exists(product_path):
        df = pd.read_csv(product_path)
        print(f"Loaded {len(df)} products from {product_path}")
    else:
        print(f"{name} CSV not found. Running scraper function...")
        df = scraper_module.scrape_products()
        df.to_csv(product_path, index=False)
        print(f"Scraped and saved {len(df)} products to {product_path}")

    df['store_name'] = name.lower().replace(' ', '_')
    df['row'] = range(1, len(df) + 1)
    df['product_id'] = df['store_name'] + "_" + df['row'].astype(str)
    
    return df

# Fetch products for each supermarket
df_ah = fetch_products("Albert Heijn", path_products_ah, ah_scraper)
df_aldi = fetch_products("Aldi", path_products_aldi, aldi_scraper)
df_jumbo = fetch_products("Jumbo", path_products_jumbo, jumbo_scraper)
# df_dirk = fetch_products("Dirk", path_products_dirk, path_scraper_dirk)
# df_lidl = fetch_products("Lidl", path_products_lidl, path_scraper_lidl)
# Out:
# Fetching Albert Heijn Products...
# Loaded 4138 products from albert_heijn/ah_products.csv
# Fetching Aldi Products...
# Loaded 1880 products from aldi/aldi_products.csv
# Fetching Jumbo Products...
# Jumbo CSV not found. Running scraper function...
# Scraping category: aardappelen_groente_fruit
# Scraping page 1 with offSet 0...
# Scraping page 2 with offSet 24...
# Scraping page 3 with offSet 48...
# Scraping page 4 with offSet 72...
# Scraping page 5 with offSet 96...
# Scraping page 6 with offSet 120...
# Scraping page 7 with offSet 144...
# Scraping page 8 with offSet 168...
# Scraping page 9 with offSet 192...
# Scraping page 10 with offSet 216...
# Scraping page 11 with offSet 240...
# Scraping page 12 with offSet 264...
# Scraping page 13 with offSet 288...
# Scraping page 14 with offSet 312...
# Scraping page 15 with offSet 336...
# Scraping page 16 with offSet 360...
# Scraping page 17 with offSet 384...
# Scraping page 18 with offSet 408...
# Scraping page 19 with offSet 432...
# Scraping page 20 with offSet 456...
# Scraping page 21 with offSet 480...
# Scraping page 22 with offSet 504...
# Scraping page 23 with offSet 528...
# Scraping page 24 with offSet 552...
# Scraping page 25 with offSet 576...
# Scraping page 26 with offSet 600...
# No more products found on page 26. Finished scraping category.
# Finished scraping category: aardappelen_groente_fruit.
# Scraping category: verse_maaltijden_gemak
# Scraping page 1 with offSet 0...
# Scraping page 2 with offSet 24...
# Scraping page 3 with offSet 48...
# Scraping page 4 with offSet 72...
# Scraping page 5 with offSet 96...
# Scraping page 6 with offSet 120...
# Scraping page 7 with offSet 144...
# Scraping page 8 with offSet 168...
# Scraping page 9 with offSet 192...
# Scraping page 10 with offSet 216...
# Scraping page 11 with offSet 240...
# Scraping page 12 with offSet 264...
# Scraping page 13 with offSet 288...
# Scraping page 14 with offSet 312...
# Scraping page 15 with offSet 336...
# Scraping page 16 with offSet 360...
# Scraping page 17 with offSet 384...
# No more products found on page 17. Finished scraping category.
# Finished scraping category: verse_maaltijden_gemak.
# Scraping category: vlees_vis_en_vega
# Scraping page 1 with offSet 0...
# Scraping page 2 with offSet 24...
# Scraping page 3 with offSet 48...
# Scraping page 4 with offSet 72...
# Scraping page 5 with offSet 96...
# Scraping page 6 with offSet 120...
# Scraping page 7 with offSet 144...
# Scraping page 8 with offSet 168...
# Scraping page 9 with offSet 192...
# Scraping page 10 with offSet 216...
# Scraping page 11 with offSet 240...
# Scraping page 12 with offSet 264...
# Scraping page 13 with offSet 288...
# Scraping page 14 with offSet 312...
# Scraping page 15 with offSet 336...
# Scraping page 16 with offSet 360...
# Scraping page 17 with offSet 384...
# Scraping page 18 with offSet 408...
# Scraping page 19 with offSet 432...
# Scraping page 20 with offSet 456...
# Scraping page 21 with offSet 480...
# Scraping page 22 with offSet 504...
# Scraping page 23 with offSet 528...
# Scraping page 24 with offSet 552...
# Scraping page 25 with offSet 576...
# Scraping page 26 with offSet 600...
# Scraping page 27 with offSet 624...
# Scraping page 28 with offSet 648...
# Scraping page 29 with offSet 672...
# Scraping page 30 with offSet 696...
# No more products found on page 30. Finished scraping category.
# Finished scraping category: vlees_vis_en_vega.
# Scraping category: brood_en_gebak
# Scraping page 1 with offSet 0...
# Scraping page 2 with offSet 24...
# Scraping page 3 with offSet 48...
# Scraping page 4 with offSet 72...
# Scraping page 5 with offSet 96...
# Scraping page 6 with offSet 120...
# Scraping page 7 with offSet 144...
# Scraping page 8 with offSet 168...
# Scraping page 9 with offSet 192...
# Scraping page 10 with offSet 216...
# Scraping page 11 with offSet 240...
# Scraping page 12 with offSet 264...
# Scraping page 13 with offSet 288...
# Scraping page 14 with offSet 312...
# No more products found on page 14. Finished scraping category.
# Finished scraping category: brood_en_gebak.
# Scraping category: vleeswaren_kaas_tapas
# Scraping page 1 with offSet 0...
# Scraping page 2 with offSet 24...
# Scraping page 3 with offSet 48...
# Scraping page 4 with offSet 72...
# Scraping page 5 with offSet 96...
# Scraping page 6 with offSet 120...
# Scraping page 7 with offSet 144...
# Scraping page 8 with offSet 168...
# Scraping page 9 with offSet 192...
# Scraping page 10 with offSet 216...
# Scraping page 11 with offSet 240...
# Scraping page 12 with offSet 264...
# Scraping page 13 with offSet 288...
# Scraping page 14 with offSet 312...
# Scraping page 15 with offSet 336...
# Scraping page 16 with offSet 360...
# Scraping page 17 with offSet 384...
# Scraping page 18 with offSet 408...
# Scraping page 19 with offSet 432...
# Scraping page 20 with offSet 456...
# Scraping page 21 with offSet 480...
# Scraping page 22 with offSet 504...
# Scraping page 23 with offSet 528...
# Scraping page 24 with offSet 552...
# Scraping page 25 with offSet 576...
# Scraping page 26 with offSet 600...
# Scraping page 27 with offSet 624...
# Scraping page 28 with offSet 648...
# Scraping page 29 with offSet 672...
# Scraping page 30 with offSet 696...
# Scraping page 31 with offSet 720...
# Scraping page 32 with offSet 744...
# Scraping page 33 with offSet 768...
# Scraping page 34 with offSet 792...
# Scraping page 35 with offSet 816...
# Scraping page 36 with offSet 840...
# Scraping page 37 with offSet 864...
# Scraping page 38 with offSet 888...
# Scraping page 39 with offSet 912...
# Scraping page 40 with offSet 936...
# Scraping page 41 with offSet 960...
# Scraping page 42 with offSet 984...
# Scraping page 43 with offSet 1008...
# Scraping page 44 with offSet 1032...
# Scraping page 45 with offSet 1056...
# Scraping page 46 with offSet 1080...
# Scraping page 47 with offSet 1104...
# Scraping page 48 with offSet 1128...
# Scraping page 49 with offSet 1152...
# Scraping page 50 with offSet 1176...
# Scraping page 51 with offSet 1200...
# Scraping page 52 with offSet 1224...
# Scraping page 53 with offSet 1248...
# Scraping page 54 with offSet 1272...
# Scraping page 55 with offSet 1296...
# Scraping page 56 with offSet 1320...
# Scraping page 57 with offSet 1344...
# Scraping page 58 with offSet 1368...
# Scraping page 59 with offSet 1392...
# No more products found on page 59. Finished scraping category.
# Finished scraping category: vleeswaren_kaas_tapas.
# Scraping category: zuivel_eieren_boter
# Scraping page 1 with offSet 0...
# Scraping page 2 with offSet 24...
# Scraping page 3 with offSet 48...
# Scraping page 4 with offSet 72...
# Scraping page 5 with offSet 96...
# Scraping page 6 with offSet 120...
# Scraping page 7 with offSet 144...
# Scraping page 8 with offSet 168...
# Scraping page 9 with offSet 192...
# Scraping page 10 with offSet 216...
# Scraping page 11 with offSet 240...
# Scraping page 12 with offSet 264...
# Scraping page 13 with offSet 288...
# Scraping page 14 with offSet 312...
# Scraping page 15 with offSet 336...
# Scraping page 16 with offSet 360...
# Scraping page 17 with offSet 384...
# Scraping page 18 with offSet 408...
# Scraping page 19 with offSet 432...
# Scraping page 20 with offSet 456...
# Scraping page 21 with offSet 480...
# Scraping page 22 with offSet 504...
# Scraping page 23 with offSet 528...
# Scraping page 24 with offSet 552...
# Scraping page 25 with offSet 576...
# Scraping page 26 with offSet 600...
# Scraping page 27 with offSet 624...
# Scraping page 28 with offSet 648...
# Scraping page 29 with offSet 672...
# Scraping page 30 with offSet 696...
# Scraping page 31 with offSet 720...
# Scraping page 32 with offSet 744...
# Scraping page 33 with offSet 768...
# Scraping page 34 with offSet 792...
# Scraping page 35 with offSet 816...
# Scraping page 36 with offSet 840...
# Scraping page 37 with offSet 864...
# Scraping page 38 with offSet 888...
# Scraping page 39 with offSet 912...
# Scraping page 40 with offSet 936...
# Scraping page 41 with offSet 960...
# Scraping page 42 with offSet 984...
# Scraping page 43 with offSet 1008...
# Scraping page 44 with offSet 1032...
# Scraping page 45 with offSet 1056...
# Scraping page 46 with offSet 1080...
# Scraping page 47 with offSet 1104...
# Scraping page 48 with offSet 1128...
# Scraping page 49 with offSet 1152...
# Scraping page 50 with offSet 1176...
# Scraping page 51 with offSet 1200...
# Scraping page 52 with offSet 1224...
# No more products found on page 52. Finished scraping category.
# Finished scraping category: zuivel_eieren_boter.
# Scraping category: conserven_soepen_sauzen_olien
# Scraping page 1 with offSet 0...
# Scraping page 2 with offSet 24...
# Scraping page 3 with offSet 48...
# Scraping page 4 with offSet 72...
# Scraping page 5 with offSet 96...
# Scraping page 6 with offSet 120...
# Scraping page 7 with offSet 144...
# Scraping page 8 with offSet 168...
# Scraping page 9 with offSet 192...
# Scraping page 10 with offSet 216...
# Scraping page 11 with offSet 240...
# Scraping page 12 with offSet 264...
# Scraping page 13 with offSet 288...
# Scraping page 14 with offSet 312...
# Scraping page 15 with offSet 336...
# Scraping page 16 with offSet 360...
# Scraping page 17 with offSet 384...
# Scraping page 18 with offSet 408...
# Scraping page 19 with offSet 432...
# Scraping page 20 with offSet 456...
# Scraping page 21 with offSet 480...
# Scraping page 22 with offSet 504...
# Scraping page 23 with offSet 528...
# Scraping page 24 with offSet 552...
# Scraping page 25 with offSet 576...
# Scraping page 26 with offSet 600...
# Scraping page 27 with offSet 624...
# Scraping page 28 with offSet 648...
# Scraping page 29 with offSet 672...
# Scraping page 30 with offSet 696...
# Scraping page 31 with offSet 720...
# Scraping page 32 with offSet 744...
# Scraping page 33 with offSet 768...
# Scraping page 34 with offSet 792...
# Scraping page 35 with offSet 816...
# Scraping page 36 with offSet 840...
# Scraping page 37 with offSet 864...
# Scraping page 38 with offSet 888...
# Scraping page 39 with offSet 912...
# Scraping page 40 with offSet 936...
# Scraping page 41 with offSet 960...
# Scraping page 42 with offSet 984...
# Scraping page 43 with offSet 1008...
# Scraping page 44 with offSet 1032...
# Scraping page 45 with offSet 1056...
# Scraping page 46 with offSet 1080...
# Scraping page 47 with offSet 1104...
# Scraping page 48 with offSet 1128...
# Scraping page 49 with offSet 1152...
# Scraping page 50 with offSet 1176...
# Scraping page 51 with offSet 1200...
# Scraping page 52 with offSet 1224...
# Scraping page 53 with offSet 1248...
# Scraping page 54 with offSet 1272...
# Scraping page 55 with offSet 1296...
# Scraping page 56 with offSet 1320...
# Scraping page 57 with offSet 1344...
# Scraping page 58 with offSet 1368...
# Scraping page 59 with offSet 1392...
# Scraping page 60 with offSet 1416...
# Scraping page 61 with offSet 1440...
# Scraping page 62 with offSet 1464...
# Scraping page 63 with offSet 1488...
# Scraping page 64 with offSet 1512...
# Scraping page 65 with offSet 1536...
# Scraping page 66 with offSet 1560...
# Scraping page 67 with offSet 1584...
# Scraping page 68 with offSet 1608...
# Scraping page 69 with offSet 1632...
# Scraping page 70 with offSet 1656...
# No more products found on page 70. Finished scraping category.
# Finished scraping category: conserven_soepen_sauzen_olien.
# Scraping category: wereldkeukens_kruiden_pasta_rijst
# Scraping page 1 with offSet 0...
# Scraping page 2 with offSet 24...
# Scraping page 3 with offSet 48...
# Scraping page 4 with offSet 72...
# Scraping page 5 with offSet 96...
# Scraping page 6 with offSet 120...
# Scraping page 7 with offSet 144...
# Scraping page 8 with offSet 168...
# Scraping page 9 with offSet 192...
# Scraping page 10 with offSet 216...
# Scraping page 11 with offSet 240...
# Scraping page 12 with offSet 264...
# Scraping page 13 with offSet 288...
# Scraping page 14 with offSet 312...
# Scraping page 15 with offSet 336...
# Scraping page 16 with offSet 360...
# Scraping page 17 with offSet 384...
# Scraping page 18 with offSet 408...
# Scraping page 19 with offSet 432...
# Scraping page 20 with offSet 456...
# Scraping page 21 with offSet 480...
# Scraping page 22 with offSet 504...
# Scraping page 23 with offSet 528...
# Scraping page 24 with offSet 552...
# Scraping page 25 with offSet 576...
# Scraping page 26 with offSet 600...
# Scraping page 27 with offSet 624...
# Scraping page 28 with offSet 648...
# Scraping page 29 with offSet 672...
# Scraping page 30 with offSet 696...
# Scraping page 31 with offSet 720...
# Scraping page 32 with offSet 744...
# Scraping page 33 with offSet 768...
# Scraping page 34 with offSet 792...
# Scraping page 35 with offSet 816...
# Scraping page 36 with offSet 840...
# Scraping page 37 with offSet 864...
# Scraping page 38 with offSet 888...
# Scraping page 39 with offSet 912...
# Scraping page 40 with offSet 936...
# Scraping page 41 with offSet 960...
# Scraping page 42 with offSet 984...
# Scraping page 43 with offSet 1008...
# Scraping page 44 with offSet 1032...
# Scraping page 45 with offSet 1056...
# Scraping page 46 with offSet 1080...
# Scraping page 47 with offSet 1104...
# Scraping page 48 with offSet 1128...
# Scraping page 49 with offSet 1152...
# Scraping page 50 with offSet 1176...
# Scraping page 51 with offSet 1200...
# Scraping page 52 with offSet 1224...
# Scraping page 53 with offSet 1248...
# Scraping page 54 with offSet 1272...
# Scraping page 55 with offSet 1296...
# Scraping page 56 with offSet 1320...
# Scraping page 57 with offSet 1344...
# Scraping page 58 with offSet 1368...
# Scraping page 59 with offSet 1392...
# Scraping page 60 with offSet 1416...
# Scraping page 61 with offSet 1440...
# Scraping page 62 with offSet 1464...
# Scraping page 63 with offSet 1488...
# Scraping page 64 with offSet 1512...
# Scraping page 65 with offSet 1536...
# Scraping page 66 with offSet 1560...
# Scraping page 67 with offSet 1584...
# Scraping page 68 with offSet 1608...
# Scraping page 69 with offSet 1632...
# Scraping page 70 with offSet 1656...
# Scraping page 71 with offSet 1680...
# Scraping page 72 with offSet 1704...
# Scraping page 73 with offSet 1728...
# Scraping page 74 with offSet 1752...
# Scraping page 75 with offSet 1776...
# Scraping page 76 with offSet 1800...
# No more products found on page 76. Finished scraping category.
# Finished scraping category: wereldkeukens_kruiden_pasta_rijst.
# Scraping category: ontbijt_broodbeleg_bakproducten
# Scraping page 1 with offSet 0...
# Scraping page 2 with offSet 24...
# Scraping page 3 with offSet 48...
# Scraping page 4 with offSet 72...
# Scraping page 5 with offSet 96...
# Scraping page 6 with offSet 120...
# Scraping page 7 with offSet 144...
# Scraping page 8 with offSet 168...
# Scraping page 9 with offSet 192...
# Scraping page 10 with offSet 216...
# Scraping page 11 with offSet 240...
# Scraping page 12 with offSet 264...
# Scraping page 13 with offSet 288...
# Scraping page 14 with offSet 312...
# Scraping page 15 with offSet 336...
# Scraping page 16 with offSet 360...
# Scraping page 17 with offSet 384...
# Scraping page 18 with offSet 408...
# Scraping page 19 with offSet 432...
# Scraping page 20 with offSet 456...
# Scraping page 21 with offSet 480...
# Scraping page 22 with offSet 504...
# Scraping page 23 with offSet 528...
# Scraping page 24 with offSet 552...
# Scraping page 25 with offSet 576...
# Scraping page 26 with offSet 600...
# Scraping page 27 with offSet 624...
# Scraping page 28 with offSet 648...
# Scraping page 29 with offSet 672...
# Scraping page 30 with offSet 696...
# Scraping page 31 with offSet 720...
# Scraping page 32 with offSet 744...
# Scraping page 33 with offSet 768...
# Scraping page 34 with offSet 792...
# Scraping page 35 with offSet 816...
# Scraping page 36 with offSet 840...
# Scraping page 37 with offSet 864...
# Scraping page 38 with offSet 888...
# Scraping page 39 with offSet 912...
# Scraping page 40 with offSet 936...
# Scraping page 41 with offSet 960...
# Scraping page 42 with offSet 984...
# Scraping page 43 with offSet 1008...
# Scraping page 44 with offSet 1032...
# Scraping page 45 with offSet 1056...
# Scraping page 46 with offSet 1080...
# Scraping page 47 with offSet 1104...
# Scraping page 48 with offSet 1128...
# Scraping page 49 with offSet 1152...
# Scraping page 50 with offSet 1176...
# Scraping page 51 with offSet 1200...
# Scraping page 52 with offSet 1224...
# Scraping page 53 with offSet 1248...
# Scraping page 54 with offSet 1272...
# Scraping page 55 with offSet 1296...
# Scraping page 56 with offSet 1320...
# No more products found on page 56. Finished scraping category.
# Finished scraping category: ontbijt_broodbeleg_bakproducten.
# Scraping category: koek_snoep_chocolade_chips
# Scraping page 1 with offSet 0...
# Scraping page 2 with offSet 24...
# Scraping page 3 with offSet 48...
# Scraping page 4 with offSet 72...
# Scraping page 5 with offSet 96...
# Scraping page 6 with offSet 120...
# Scraping page 7 with offSet 144...
# Scraping page 8 with offSet 168...
# Scraping page 9 with offSet 192...
# Scraping page 10 with offSet 216...
# Scraping page 11 with offSet 240...
# Scraping page 12 with offSet 264...
# Scraping page 13 with offSet 288...
# Scraping page 14 with offSet 312...
# Scraping page 15 with offSet 336...
# Scraping page 16 with offSet 360...
# Scraping page 17 with offSet 384...
# Scraping page 18 with offSet 408...
# Scraping page 19 with offSet 432...
# Scraping page 20 with offSet 456...
# Scraping page 21 with offSet 480...
# Scraping page 22 with offSet 504...
# Scraping page 23 with offSet 528...
# Scraping page 24 with offSet 552...
# Scraping page 25 with offSet 576...
# Scraping page 26 with offSet 600...
# Scraping page 27 with offSet 624...
# Scraping page 28 with offSet 648...
# Scraping page 29 with offSet 672...
# Scraping page 30 with offSet 696...
# Scraping page 31 with offSet 720...
# Scraping page 32 with offSet 744...
# Scraping page 33 with offSet 768...
# Scraping page 34 with offSet 792...
# Scraping page 35 with offSet 816...
# Scraping page 36 with offSet 840...
# Scraping page 37 with offSet 864...
# Scraping page 38 with offSet 888...
# Scraping page 39 with offSet 912...
# Scraping page 40 with offSet 936...
# Scraping page 41 with offSet 960...
# Scraping page 42 with offSet 984...
# Scraping page 43 with offSet 1008...
# Scraping page 44 with offSet 1032...
# Scraping page 45 with offSet 1056...
# Scraping page 46 with offSet 1080...
# Scraping page 47 with offSet 1104...
# Scraping page 48 with offSet 1128...
# Scraping page 49 with offSet 1152...
# Scraping page 50 with offSet 1176...
# Scraping page 51 with offSet 1200...
# Scraping page 52 with offSet 1224...
# Scraping page 53 with offSet 1248...
# Scraping page 54 with offSet 1272...
# Scraping page 55 with offSet 1296...
# Scraping page 56 with offSet 1320...
# Scraping page 57 with offSet 1344...
# Scraping page 58 with offSet 1368...
# Scraping page 59 with offSet 1392...
# Scraping page 60 with offSet 1416...
# Scraping page 61 with offSet 1440...
# Scraping page 62 with offSet 1464...
# Scraping page 63 with offSet 1488...
# Scraping page 64 with offSet 1512...
# Scraping page 65 with offSet 1536...
# Scraping page 66 with offSet 1560...
# Scraping page 67 with offSet 1584...
# Scraping page 68 with offSet 1608...
# Scraping page 69 with offSet 1632...
# Scraping page 70 with offSet 1656...
# Scraping page 71 with offSet 1680...
# Scraping page 72 with offSet 1704...
# Scraping page 73 with offSet 1728...
# Scraping page 74 with offSet 1752...
# Scraping page 75 with offSet 1776...
# Scraping page 76 with offSet 1800...
# Scraping page 77 with offSet 1824...
# Scraping page 78 with offSet 1848...
# Scraping page 79 with offSet 1872...
# Scraping page 80 with offSet 1896...
# Scraping page 81 with offSet 1920...
# Scraping page 82 with offSet 1944...
# Scraping page 83 with offSet 1968...
# Scraping page 84 with offSet 1992...
# Scraping page 85 with offSet 2016...
# Scraping page 86 with offSet 2040...
# Scraping page 87 with offSet 2064...
# Scraping page 88 with offSet 2088...
# Scraping page 89 with offSet 2112...
# Scraping page 90 with offSet 2136...
# No more products found on page 90. Finished scraping category.
# Finished scraping category: koek_snoep_chocolade_chips.
# Scraping category: koffie_thee
# Scraping page 1 with offSet 0...
# Scraping page 2 with offSet 24...
# Scraping page 3 with offSet 48...
# Scraping page 4 with offSet 72...
# Scraping page 5 with offSet 96...
# Scraping page 6 with offSet 120...
# Scraping page 7 with offSet 144...
# Scraping page 8 with offSet 168...
# Scraping page 9 with offSet 192...
# Scraping page 10 with offSet 216...
# Scraping page 11 with offSet 240...
# Scraping page 12 with offSet 264...
# Scraping page 13 with offSet 288...
# Scraping page 14 with offSet 312...
# Scraping page 15 with offSet 336...
# Scraping page 16 with offSet 360...
# Scraping page 17 with offSet 384...
# Scraping page 18 with offSet 408...
# Scraping page 19 with offSet 432...
# Scraping page 20 with offSet 456...
# Scraping page 21 with offSet 480...
# Scraping page 22 with offSet 504...
# Scraping page 23 with offSet 528...
# Scraping page 24 with offSet 552...
# Scraping page 25 with offSet 576...
# Scraping page 26 with offSet 600...
# Scraping page 27 with offSet 624...
# Scraping page 28 with offSet 648...
# Scraping page 29 with offSet 672...
# Scraping page 30 with offSet 696...
# Scraping page 31 with offSet 720...
# Scraping page 32 with offSet 744...
# Scraping page 33 with offSet 768...
# Scraping page 34 with offSet 792...
# Scraping page 35 with offSet 816...
# No more products found on page 35. Finished scraping category.
# Finished scraping category: koffie_thee.
# Scraping category: frisdrank_sappen
# Scraping page 1 with offSet 0...
# Scraping page 2 with offSet 24...
# Scraping page 3 with offSet 48...
# Scraping page 4 with offSet 72...
# Scraping page 5 with offSet 96...
# Scraping page 6 with offSet 120...
# Scraping page 7 with offSet 144...
# Scraping page 8 with offSet 168...
# Scraping page 9 with offSet 192...
# Scraping page 10 with offSet 216...
# Scraping page 11 with offSet 240...
# Scraping page 12 with offSet 264...
# Scraping page 13 with offSet 288...
# Scraping page 14 with offSet 312...
# Scraping page 15 with offSet 336...
# Scraping page 16 with offSet 360...
# Scraping page 17 with offSet 384...
# Scraping page 18 with offSet 408...
# Scraping page 19 with offSet 432...
# Scraping page 20 with offSet 456...
# Scraping page 21 with offSet 480...
# Scraping page 22 with offSet 504...
# Scraping page 23 with offSet 528...
# Scraping page 24 with offSet 552...
# Scraping page 25 with offSet 576...
# Scraping page 26 with offSet 600...
# Scraping page 27 with offSet 624...
# Scraping page 28 with offSet 648...
# Scraping page 29 with offSet 672...
# Scraping page 30 with offSet 696...
# Scraping page 31 with offSet 720...
# Scraping page 32 with offSet 744...
# Scraping page 33 with offSet 768...
# Scraping page 34 with offSet 792...
# Scraping page 35 with offSet 816...
# Scraping page 36 with offSet 840...
# Scraping page 37 with offSet 864...
# Scraping page 38 with offSet 888...
# Scraping page 39 with offSet 912...
# Scraping page 40 with offSet 936...
# Scraping page 41 with offSet 960...
# Scraping page 42 with offSet 984...
# Scraping page 43 with offSet 1008...
# Scraping page 44 with offSet 1032...
# Scraping page 45 with offSet 1056...
# Scraping page 46 with offSet 1080...
# Scraping page 47 with offSet 1104...
# Scraping page 48 with offSet 1128...
# Scraping page 49 with offSet 1152...
# Scraping page 50 with offSet 1176...
# Scraping page 51 with offSet 1200...
# Scraping page 52 with offSet 1224...
# Scraping page 53 with offSet 1248...
# No more products found on page 53. Finished scraping category.
# Finished scraping category: frisdrank_sappen.
# Scraping category: bier_wijn
# Scraping page 1 with offSet 0...
# Scraping page 2 with offSet 24...
# Scraping page 3 with offSet 48...
# Scraping page 4 with offSet 72...
# Scraping page 5 with offSet 96...
# Scraping page 6 with offSet 120...
# Scraping page 7 with offSet 144...
# Scraping page 8 with offSet 168...
# Scraping page 9 with offSet 192...
# Scraping page 10 with offSet 216...
# Scraping page 11 with offSet 240...
# Scraping page 12 with offSet 264...
# Scraping page 13 with offSet 288...
# Scraping page 14 with offSet 312...
# Scraping page 15 with offSet 336...
# Scraping page 16 with offSet 360...
# Scraping page 17 with offSet 384...
# Scraping page 18 with offSet 408...
# Scraping page 19 with offSet 432...
# Scraping page 20 with offSet 456...
# Scraping page 21 with offSet 480...
# Scraping page 22 with offSet 504...
# Scraping page 23 with offSet 528...
# Scraping page 24 with offSet 552...
# Scraping page 25 with offSet 576...
# Scraping page 26 with offSet 600...
# Scraping page 27 with offSet 624...
# Scraping page 28 with offSet 648...
# Scraping page 29 with offSet 672...
# Scraping page 30 with offSet 696...
# Scraping page 31 with offSet 720...
# Scraping page 32 with offSet 744...
# Scraping page 33 with offSet 768...
# Scraping page 34 with offSet 792...
# Scraping page 35 with offSet 816...
# Scraping page 36 with offSet 840...
# Scraping page 37 with offSet 864...
# Scraping page 38 with offSet 888...
# Scraping page 39 with offSet 912...
# Scraping page 40 with offSet 936...
# Scraping page 41 with offSet 960...
# Scraping page 42 with offSet 984...
# Scraping page 43 with offSet 1008...
# Scraping page 44 with offSet 1032...
# Scraping page 45 with offSet 1056...
# Scraping page 46 with offSet 1080...
# Scraping page 47 with offSet 1104...
# Scraping page 48 with offSet 1128...
# Scraping page 49 with offSet 1152...
# Scraping page 50 with offSet 1176...
# Scraping page 51 with offSet 1200...
# Scraping page 52 with offSet 1224...
# Scraping page 53 with offSet 1248...
# Scraping page 54 with offSet 1272...
# Scraping page 55 with offSet 1296...
# Scraping page 56 with offSet 1320...
# Scraping page 57 with offSet 1344...
# Scraping page 58 with offSet 1368...
# Scraping page 59 with offSet 1392...
# Scraping page 60 with offSet 1416...
# Scraping page 61 with offSet 1440...
# Scraping page 62 with offSet 1464...
# Scraping page 63 with offSet 1488...
# Scraping page 64 with offSet 1512...
# No more products found on page 64. Finished scraping category.
# Finished scraping category: bier_wijn.
# Scraping category: diepvries
# Scraping page 1 with offSet 0...
# Scraping page 2 with offSet 24...
# Scraping page 3 with offSet 48...
# Scraping page 4 with offSet 72...
# Scraping page 5 with offSet 96...
# Scraping page 6 with offSet 120...
# Scraping page 7 with offSet 144...
# Scraping page 8 with offSet 168...
# Scraping page 9 with offSet 192...
# Scraping page 10 with offSet 216...
# Scraping page 11 with offSet 240...
# Scraping page 12 with offSet 264...
# Scraping page 13 with offSet 288...
# Scraping page 14 with offSet 312...
# Scraping page 15 with offSet 336...
# Scraping page 16 with offSet 360...
# Scraping page 17 with offSet 384...
# Scraping page 18 with offSet 408...
# Scraping page 19 with offSet 432...
# Scraping page 20 with offSet 456...
# Scraping page 21 with offSet 480...
# Scraping page 22 with offSet 504...
# Scraping page 23 with offSet 528...
# Scraping page 24 with offSet 552...
# Scraping page 25 with offSet 576...
# Scraping page 26 with offSet 600...
# Scraping page 27 with offSet 624...
# Scraping page 28 with offSet 648...
# Scraping page 29 with offSet 672...
# Scraping page 30 with offSet 696...
# Scraping page 31 with offSet 720...
# Scraping page 32 with offSet 744...
# Scraping page 33 with offSet 768...
# Scraping page 34 with offSet 792...
# Scraping page 35 with offSet 816...
# Scraping page 36 with offSet 840...
# Scraping page 37 with offSet 864...
# Scraping page 38 with offSet 888...
# Scraping page 39 with offSet 912...
# No more products found on page 39. Finished scraping category.
# Finished scraping category: diepvries.
# Scraping category: drogisterij
# Scraping page 1 with offSet 0...
# Scraping page 2 with offSet 24...
# Scraping page 3 with offSet 48...
# Scraping page 4 with offSet 72...
# Scraping page 5 with offSet 96...
# Scraping page 6 with offSet 120...
# Scraping page 7 with offSet 144...
# Scraping page 8 with offSet 168...
# Scraping page 9 with offSet 192...
# Scraping page 10 with offSet 216...
# Scraping page 11 with offSet 240...
# Scraping page 12 with offSet 264...
# Scraping page 13 with offSet 288...
# Scraping page 14 with offSet 312...
# Scraping page 15 with offSet 336...
# Scraping page 16 with offSet 360...
# Scraping page 17 with offSet 384...
# Scraping page 18 with offSet 408...
# Scraping page 19 with offSet 432...
# Scraping page 20 with offSet 456...
# Scraping page 21 with offSet 480...
# Scraping page 22 with offSet 504...
# Scraping page 23 with offSet 528...
# Scraping page 24 with offSet 552...
# Scraping page 25 with offSet 576...
# Scraping page 26 with offSet 600...
# Scraping page 27 with offSet 624...
# Scraping page 28 with offSet 648...
# Scraping page 29 with offSet 672...
# Scraping page 30 with offSet 696...
# Scraping page 31 with offSet 720...
# Scraping page 32 with offSet 744...
# Scraping page 33 with offSet 768...
# Scraping page 34 with offSet 792...
# Scraping page 35 with offSet 816...
# Scraping page 36 with offSet 840...
# Scraping page 37 with offSet 864...
# Scraping page 38 with offSet 888...
# Scraping page 39 with offSet 912...
# Scraping page 40 with offSet 936...
# Scraping page 41 with offSet 960...
# Scraping page 42 with offSet 984...
# Scraping page 43 with offSet 1008...
# Scraping page 44 with offSet 1032...
# Scraping page 45 with offSet 1056...
# Scraping page 46 with offSet 1080...
# Scraping page 47 with offSet 1104...
# Scraping page 48 with offSet 1128...
# Scraping page 49 with offSet 1152...
# Scraping page 50 with offSet 1176...
# Scraping page 51 with offSet 1200...
# Scraping page 52 with offSet 1224...
# Scraping page 53 with offSet 1248...
# Scraping page 54 with offSet 1272...
# Scraping page 55 with offSet 1296...
# Scraping page 56 with offSet 1320...
# Scraping page 57 with offSet 1344...
# Scraping page 58 with offSet 1368...
# No more products found on page 58. Finished scraping category.
# Finished scraping category: drogisterij.
# Scraping category: baby_peuter
# Scraping page 1 with offSet 0...
# Scraping page 2 with offSet 24...
# Scraping page 3 with offSet 48...
# Scraping page 4 with offSet 72...
# Scraping page 5 with offSet 96...
# Scraping page 6 with offSet 120...
# Scraping page 7 with offSet 144...
# Scraping page 8 with offSet 168...
# Scraping page 9 with offSet 192...
# Scraping page 10 with offSet 216...
# Scraping page 11 with offSet 240...
# Scraping page 12 with offSet 264...
# Scraping page 13 with offSet 288...
# Scraping page 14 with offSet 312...
# Scraping page 15 with offSet 336...
# Scraping page 16 with offSet 360...
# Scraping page 17 with offSet 384...
# Scraping page 18 with offSet 408...
# Scraping page 19 with offSet 432...
# Scraping page 20 with offSet 456...
# Scraping page 21 with offSet 480...
# Scraping page 22 with offSet 504...
# Scraping page 23 with offSet 528...
# Scraping page 24 with offSet 552...
# Scraping page 25 with offSet 576...
# Scraping page 26 with offSet 600...
# No more products found on page 26. Finished scraping category.
# Finished scraping category: baby_peuter.
# Scraping category: huishouden_dieren_servicebalie
# Scraping page 1 with offSet 0...
# Scraping page 2 with offSet 24...
# Scraping page 3 with offSet 48...
# Scraping page 4 with offSet 72...
# Scraping page 5 with offSet 96...
# Scraping page 6 with offSet 120...
# Scraping page 7 with offSet 144...
# Scraping page 8 with offSet 168...
# Scraping page 9 with offSet 192...
# Scraping page 10 with offSet 216...
# Scraping page 11 with offSet 240...
# Scraping page 12 with offSet 264...
# Scraping page 13 with offSet 288...
# Scraping page 14 with offSet 312...
# Scraping page 15 with offSet 336...
# Scraping page 543 with offSet 13008...
# Scraping page 544 with offSet 13032...
# Scraping page 545 with offSet 13056...
# Scraping page 546 with offSet 13080...
# Scraping page 547 with offSet 13104...
# Scraping page 548 with offSet 13128...
# Scraping page 549 with offSet 13152...
# Scraping page 550 with offSet 13176...
# Scraping page 551 with offSet 13200...
# Scraping page 552 with offSet 13224...
# Scraping page 553 with offSet 13248...
# Scraping page 554 with offSet 13272...
# Scraping page 555 with offSet 13296...
# Scraping page 556 with offSet 13320...
# Scraping page 557 with offSet 13344...
# Scraping page 558 with offSet 13368...
# Scraping page 559 with offSet 13392...
# Scraping page 560 with offSet 13416...
# Scraping page 561 with offSet 13440...
# Scraping page 562 with offSet 13464...
# Scraping page 563 with offSet 13488...
# Scraping page 564 with offSet 13512...
# Scraping page 565 with offSet 13536...
# Scraping page 566 with offSet 13560...
# Scraping page 567 with offSet 13584...
# Scraping page 568 with offSet 13608...
# Scraping page 569 with offSet 13632...
# Scraping page 570 with offSet 13656...
# Scraping page 571 with offSet 13680...
# Scraping page 572 with offSet 13704...
# Scraping page 573 with offSet 13728...
# Scraping page 574 with offSet 13752...
# Scraping page 575 with offSet 13776...
# Scraping page 576 with offSet 13800...
# Scraping page 577 with offSet 13824...
# Scraping page 578 with offSet 13848...
# Scraping page 579 with offSet 13872...
# Scraping page 580 with offSet 13896...
# Scraping page 581 with offSet 13920...
# Scraping page 582 with offSet 13944...
# Scraping page 583 with offSet 13968...
# Scraping page 584 with offSet 13992...
# Scraping page 585 with offSet 14016...
# Scraping page 586 with offSet 14040...
# Scraping page 587 with offSet 14064...
# Scraping page 588 with offSet 14088...
# Scraping page 589 with offSet 14112...
# Scraping page 590 with offSet 14136...
# Scraping page 591 with offSet 14160...
# Scraping page 592 with offSet 14184...
# Scraping page 593 with offSet 14208...
# Scraping page 594 with offSet 14232...
# Scraping page 595 with offSet 14256...
# Scraping page 596 with offSet 14280...
# Scraping page 597 with offSet 14304...
# Scraping page 598 with offSet 14328...
# Scraping page 599 with offSet 14352...
# Scraping page 600 with offSet 14376...
# Scraping page 601 with offSet 14400...
# Scraping page 602 with offSet 14424...
# Scraping page 603 with offSet 14448...
# Scraping page 604 with offSet 14472...
# Scraping page 605 with offSet 14496...
# Scraping page 606 with offSet 14520...
# Scraping page 607 with offSet 14544...
# Scraping page 608 with offSet 14568...
# Scraping page 609 with offSet 14592...
# Scraping page 610 with offSet 14616...
# Scraping page 611 with offSet 14640...
# Scraping page 612 with offSet 14664...
# Scraping page 613 with offSet 14688...
# Scraping page 614 with offSet 14712...
# Scraping page 615 with offSet 14736...
# Scraping page 616 with offSet 14760...
# Scraping page 617 with offSet 14784...
# Scraping page 618 with offSet 14808...
# Scraping page 619 with offSet 14832...
# Scraping page 620 with offSet 14856...
# Scraping page 621 with offSet 14880...
# Scraping page 622 with offSet 14904...
# Scraping page 623 with offSet 14928...
# Scraping page 624 with offSet 14952...
# Scraping page 625 with offSet 14976...
# Scraping page 626 with offSet 15000...
# Scraping page 627 with offSet 15024...
# Scraping page 628 with offSet 15048...
# Scraping page 629 with offSet 15072...
# Scraping page 630 with offSet 15096...
# Scraping page 631 with offSet 15120...
# Scraping page 632 with offSet 15144...
# Scraping page 633 with offSet 15168...
# Scraping page 634 with offSet 15192...
# Scraping page 635 with offSet 15216...
# Scraping page 636 with offSet 15240...
# Scraping page 637 with offSet 15264...
# Scraping page 638 with offSet 15288...
# Scraping page 639 with offSet 15312...
# Scraping page 640 with offSet 15336...
# Scraping page 641 with offSet 15360...
# Scraping page 642 with offSet 15384...
# Scraping page 643 with offSet 15408...
# Scraping page 644 with offSet 15432...
# Scraping page 645 with offSet 15456...
# Scraping page 646 with offSet 15480...
# Scraping page 647 with offSet 15504...
# Scraping page 648 with offSet 15528...
# Scraping page 649 with offSet 15552...
# Scraping page 650 with offSet 15576...
# Scraping page 651 with offSet 15600...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 21
#      19 df_ah = fetch_products("Albert Heijn", path_products_ah, ah_scraper)
#      20 df_aldi = fetch_products("Aldi", path_products_aldi, aldi_scraper)
# ---> 21 df_jumbo = fetch_products("Jumbo", path_products_jumbo, jumbo_scraper)
#      22 # df_dirk = fetch_products("Dirk", path_products_dirk, path_scraper_dirk)
#      23 # df_lidl = fetch_products("Lidl", path_products_lidl, path_scraper_lidl)
#
# Cell In[4], line 8, in fetch_products(name, product_path, scraper_module)
#       6 else:
#       7     print(f"{name} CSV not found. Running scraper function...")
# ----> 8     df = scraper_module.scrape_products()
#       9     df.to_csv(product_path, index=False)
#      10     print(f"Scraped and saved {len(df)} products to {product_path}")
#
# File c:\Users\iamth\Desktop\Sasta\app\scraping\jumbo\jumbo_scraper.py:112, in scrape_products()
#     110 # Iterate over each category and scrape it
#     111 for category_name, category_url in categories.items():
# --> 112     scrape_category(category_name, category_url)
#     114 # Convert the list of dictionaries to a DataFrame
#     115 df = pd.DataFrame(all_products)
#
# File c:\Users\iamth\Desktop\Sasta\app\scraping\jumbo\jumbo_scraper.py:52, in scrape_products.<locals>.scrape_category(category_name, category_url)
#      49 url = f"{category_url}?offSet={offSet}"
#      51 # Send a GET request to the website
# ---> 52 response = requests.get(url, headers=headers)
#      54 # Parse the content with BeautifulSoup
#      55 soup = BeautifulSoup(response.content, 'lxml')
#
# File c:\Users\iamth\Desktop\Sasta\app\venv\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\iamth\Desktop\Sasta\app\venv\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\iamth\Desktop\Sasta\app\venv\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\iamth\Desktop\Sasta\app\venv\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\iamth\Desktop\Sasta\app\venv\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\iamth\Desktop\Sasta\app\venv\lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\Users\iamth\Desktop\Sasta\app\venv\lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\iamth\Desktop\Sasta\app\venv\lib\site-packages\urllib3\connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# df_jumbo

# %%
# removing products who price is not listed
df_ah = df_ah.dropna(subset=['product_price'])
df_ah = df_ah.reindex(columns=['product_id', 'product_name', 'product_category', 'product_link', 'product_price', 'product_quantity', 'store_name'])

df_aldi = df_aldi.dropna(subset=['product_price'])
df_aldi = df_aldi.reindex(columns=['product_id', 'product_name', 'product_category', 'product_link', 'product_price', 'product_quantity', 'store_name'])

# %%
print("Number of ALDI products : ", df_aldi.shape[0])
print("Number of AH products : ", df_ah.shape[0])
# Out:
# Number of ALDI products :  1880
# Number of AH products :  4138

# %%
df_all_products = pd.concat([df_ah, df_aldi])

# %%
df_all_products.to_csv("df_all_products.csv", header=True)
