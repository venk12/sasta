# %%
import pandas as pd
from rapidfuzz import process, fuzz
import os

# %%
my_grocery_list_df = pd.read_csv('sample_list.csv', index_col= False, header=0)
my_grocery_list_df = my_grocery_list_df.drop(columns=['Unnamed: 0'])
my_grocery_list_df.columns = ['Ingredients', 'Amount', 'Quantity']

# %%
my_grocery_list_df.head()
# Out:
#   Ingredients Amount Quantity
# 0       Rijst    300     gram
# 1         Kip    300     gram
# 2     Yoghurt    100       ml
# 3        Uien      2    stuks
# 4     Tomaten      2    stuks

# %%
df_all_products = pd.read_csv("df_all_products.csv")
df_all_products.head(2)
# Out:
#    Unnamed: 0      product_id                    product_name  \
# 0           0  albert_heijn_1  Zespri kiwi sungoldAdvertentie
# 1           1  albert_heijn_2     Zespri Kiwi goldAdvertentie
#
#             product_category  \
# 0  Aardappel, groente, fruit
# 1  Aardappel, groente, fruit
#
#                                         product_link product_price  \
# 0  https://www.ah.nl/producten/product/wi367212/z...          5.99
# 1  https://www.ah.nl/producten/product/wi523724/z...          2.99
#
#   product_quantity    store_name
# 0            750 g  albert_heijn
# 1          3 stuks  albert_heijn

# %%
# Step 2: Define a function for fuzzy matching with a confidence threshold
def fuzzy_match(item_name, choices, scorer=fuzz.WRatio, threshold=90):
    match = process.extractOne(item_name, choices, scorer=scorer)
    if match and match[1] >= threshold:
        return match[0]
    return None

# Step 3: Create a list to hold the matches
matches = []

# Step 4: Perform fuzzy matching for each item in my_grocery_list_df with a high confidence threshold
for item in my_grocery_list_df['Ingredients']:
    match = fuzzy_match(item, df_all_products['product_name'], threshold=90)
    matches.append(match)

# Step 5: Add the matches to the my_grocery_list_df
my_grocery_list_df['Matched Product'] = matches

# Step 6: Merge the DataFrames on the matched product name to include 'Price' and 'Image URL'
merged_df = pd.merge(
    my_grocery_list_df, 
    df_all_products[['product_name', 'product_price', 'product_link', 'product_quantity', 'store_name']], 
    how='left', 
    left_on='Matched Product', 
    right_on='product_name'
)

# Drop the duplicate 'Product Name' column
merged_df.drop(columns=['product_name'], inplace=True)

# Display the merged DataFrame
merged_df.head()
# Out:
#   Ingredients Amount Quantity                    Matched Product  \
# 0       Rijst    300     gram  AH Biologisch Rijstwafels naturel
# 1       Rijst    300     gram  AH Biologisch Rijstwafels naturel
# 2         Kip    300     gram             Wahid Kipfilet naturel
# 3         Kip    300     gram             Wahid Kipfilet naturel
# 4         Kip    300     gram             Wahid Kipfilet naturel
#
#   product_price                                       product_link  \
# 0          0.75  https://www.ah.nl/producten/product/wi58492/ah...
# 1          0.75  https://www.ah.nl/producten/product/wi58492/ah...
# 2          2.49  https://www.ah.nl/producten/product/wi162009/w...
# 3          2.49  https://www.ah.nl/producten/product/wi162009/w...
# 4          2.49  https://www.ah.nl/producten/product/wi162009/w...
#
#   product_quantity    store_name
# 0         13 stuks  albert_heijn
# 1         13 stuks  albert_heijn
# 2            125 g  albert_heijn
# 3            125 g  albert_heijn
# 4            125 g  albert_heijn

# %%
print(merged_df.to_string())
# Out:
#           Ingredients      Amount    Quantity                                Matched Product product_price                                                                                                                                                                                      product_link product_quantity    store_name
# 0               Rijst         300        gram              AH Biologisch Rijstwafels naturel          0.75                                                                                                                     https://www.ah.nl/producten/product/wi58492/ah-biologisch-rijstwafels-naturel         13 stuks  albert_heijn
# 1               Rijst         300        gram              AH Biologisch Rijstwafels naturel          0.75                                                                                                                     https://www.ah.nl/producten/product/wi58492/ah-biologisch-rijstwafels-naturel         13 stuks  albert_heijn
# 2                 Kip         300        gram                         Wahid Kipfilet naturel          2.49                                                                                                                               https://www.ah.nl/producten/product/wi162009/wahid-kipfilet-naturel            125 g  albert_heijn
# 3                 Kip         300        gram                         Wahid Kipfilet naturel          2.49                                                                                                                               https://www.ah.nl/producten/product/wi162009/wahid-kipfilet-naturel            125 g  albert_heijn
# 4                 Kip         300        gram                         Wahid Kipfilet naturel          2.49                                                                                                                               https://www.ah.nl/producten/product/wi162009/wahid-kipfilet-naturel            125 g  albert_heijn
# 5             Yoghurt         100          ml  Melkunie Yoghurt smoothie framboosAdvertentie          1.69                                                                                                                   https://www.ah.nl/producten/product/wi575543/melkunie-yoghurt-smoothie-framboos           350 ml  albert_heijn
# 6                Uien           2       stuks                                           Uien           NaN                           https://www.aldi.nl//content/aldi/netherlands/nl/web-consumer/producten/aardappels-groente-fruit/groenten/jcr:content/par/tiles/par/articletile7_copy_co_202272573.html             2 kg          aldi
# 7                Uien           2       stuks                                           Uien           NaN                           https://www.aldi.nl//content/aldi/netherlands/nl/web-consumer/producten/aardappels-groente-fruit/groenten/jcr:content/par/tiles/par/articletile7_copy_co_292712949.html            750 g          aldi
# 8             Tomaten           2       stuks                                        Tomaten           NaN               https://www.aldi.nl//content/aldi/netherlands/nl/web-consumer/producten/aardappels-groente-fruit/groenten/jcr:content/par/tiles_1867965116/par/articletile6_copy_co_2099707433.html            500-g          aldi
# 9            Knoflook           4    teentjes                                       Knoflook           NaN                                       https://www.aldi.nl//content/aldi/netherlands/nl/web-consumer/producten/aardappels-groente-fruit/groenten/jcr:content/par/tiles/par/articletile19_copy.html          2 stuks          aldi
# 10           Knoflook           4    teentjes                                       Knoflook           NaN  https://www.aldi.nl//content/aldi/netherlands/nl/web-consumer/producten/soepen-sauzen-smaakmakers-conserven/kruiden-aromas-en-azijn/jcr:content/par/tiles/par/articletile17_copy_2143529814.html          2 stuks          aldi
# 11             Gember           1      stukje                                         Gember           NaN                https://www.aldi.nl//content/aldi/netherlands/nl/web-consumer/producten/aardappels-groente-fruit/groenten/jcr:content/par/tiles_1867965116/par/articletile_13113806_371854717.html       Los per kg          aldi
# 12       Groene peper           2       stuks                                           None           NaN                                                                                                                                                                                               NaN              NaN           NaN
# 13       Muntblaadjes  een handje         NaN                                           Munt           NaN                          https://www.aldi.nl//content/aldi/netherlands/nl/web-consumer/producten/aardappels-groente-fruit/groenten/jcr:content/par/tiles/par/articletile_36688333_1296956700.html             30 g          aldi
# 14  Korianderblaadjes  een handje         NaN                                      Koriander           NaN                           https://www.aldi.nl//content/aldi/netherlands/nl/web-consumer/producten/aardappels-groente-fruit/groenten/jcr:content/par/tiles/par/articletile_36688333_575174664.html             20 g          aldi
# 15       Garam masala           2  theelepels                                           None           NaN                                                                                                                                                                                               NaN              NaN           NaN
# 16         Komijnzaad           1   theelepel                                           None           NaN                                                                                                                                                                                               NaN              NaN           NaN
# 17       Kaneelstokje           1      stukje                                           None           NaN                                                                                                                                                                                               NaN              NaN           NaN
# 18        Kruidnagels           3       stuks                                           None           NaN                                                                                                                                                                                               NaN              NaN           NaN
# 19           Kardemom           2       stuks                                           None           NaN                                                                                                                                                                                               NaN              NaN           NaN
# 20               Zout  naar smaak         NaN                         Bolletje Zoute pepsels          1.39                                                                                                                               https://www.ah.nl/producten/product/wi448430/bolletje-zoute-pepsels            180 g  albert_heijn
# 21               Olie           4   eetlepels                            Oliehoorn Currysaus          3.79                                                                                                                                  https://www.ah.nl/producten/product/wi516341/oliehoorn-currysaus           0,75 l  albert_heijn
